# %% [markdown]
# <a href="https://colab.research.google.com/github/chimmykk/MemeMachine/blob/main/trainmodel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U torch torchvision
# !pip install pyyaml
# !pip install git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI
# Out:
# ...
#   Cloning https://github.com/cocodataset/cocoapi.git to /private/var/folders/2t/pqvc0bs10nq8g9dvv3fytqlm0000gn/T/pip-req-build-n57hrvdw
#   Running command git clone --filter=blob:none --quiet https://github.com/cocodataset/cocoapi.git /private/var/folders/2t/pqvc0bs10nq8g9dvv3fytqlm0000gn/T/pip-req-build-n57hrvdw
#   Resolved https://github.com/cocodataset/cocoapi.git to commit 8c9bcc3cf640524c4c20a9c40e89cb6a2f2fa0e9
# done
# ...

# %%
ls
# Out:
# Applications/               Public/
# Desktop/                    Untitled.ipynb
# Documents/                  Virtual Machines.localized/
# Downloads/                  anaconda3/
# ETHBOT/                     miniconda3/
# Library/                    my-app/
# Movies/                     nltk_data/
# Music/                      test/
# Parallels/                  websites/
# Pictures/

# %%
cd anaconda3/
# Out:
# /Users/yeiterilsosingkoireng/anaconda3

# %%
ls
# Out:
# Anaconda-Navigator.app/ insight-face.ipynb      qml/
# Untitled.ipynb          lib/                    resources/
# Untitled1.ipynb         libexec/                sbin/
# bin/                    man/                    share/
# conda-meta/             memegen/                shell/
# condabin/               mkspecs/                ssl/
# doc/                    pkgs/                   trainmodel/
# envs/                   plugins/                translations/
# etc/                    pyodbc.pyi              untitled.txt
# include/                python.app/

# %%
cd trainmodel/
# Out:
# /Users/yeiterilsosingkoireng/anaconda3/trainmodel

# %%
ls
# Out:
# Untitled.ipynb   Untitled1.ipynb  train_data/      yolov5/

# %%
cd yolov5/
# Out:
# /Users/yeiterilsosingkoireng/anaconda3/trainmodel/yolov5

# %%
# !pip install -r requirements.txt

# %%
ls
# Out:
# CITATION.cff      benchmarks.py     models/           tutorial.ipynb
# CONTRIBUTING.md   classify/         requirements.txt  utils/
# LICENSE           data/             runs/             val.py
# README.md         detect.py         segment/          yolov5/
# README.zh-CN.md   export.py         setup.cfg         yolov5s.pt
# __pycache__/      hubconf.py        train.py

# %%
# !python3 train.py
# Out:
# train: weights=yolov5s.pt, cfg=, data=data/custom_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-193-g485da42 Python-3.11.3 torch-2.0.1 CPU
#
# ...
